# %%
print "Hello"
# Out:
# Hello

# %%
import os
import pandas as pd

#df = pd.read_csv('/home/venky/IdeaProjects/ViterbiHack/MacMapping.txt', sep=" ", header=None, names=["mac", "name"])

f = open("/home/venky/IdeaProjects/ViterbiHack/MacMapping.txt","r")
blob = f.readlines()

#print blob
dict_mac = {}

my_set = set([])
for row in blob:
    my_set.add(row.strip()[7:])
    dict_mac[row.strip()[0:6]]=row.strip()[7:]
    
print len(my_set),len(blob)

print dict_mac
# Out:
# 17112 24712
# ...

# %%
my_dict = {}
for counter, value in enumerate(my_set):
    my_dict[value] = counter

print my_dict
# Out:
# {'Beijing Siasun Electronic System Co.,Ltd.': 0, 'Anedo Ltd.': 1, 'Hanwha Techwin Security Vietnam': 2, 'CYZENTECH Co., Ltd.': 3, 'Ticom Geomatics, Inc.': 4, 'SOLIDUM SYSTEMS CORP.': 5, 'Htel': 7621, 'DOSCH & AMAND SYSTEMS AG': 7, 'EWM Hightec Welding GmbH': 5666, 'Challenger Supply Holdings, LLC': 9, 'MusicianLink': 10, 'HEXIUM Technical Development Co., Ltd.': 11, 'Day One Digital Media Limited': 12, 'Micronik Multimedia': 77, 'SeorimTechnology Co.,Ltd.': 14, 'A. S. Thomas, Inc.': 15, 'Overland Storage, Inc.': 16, 'M-Audio': 17, 'BNS Solutions': 18, 'MCS Logic Inc.': 19, 'TriState Ltd.': 20, 'SAIC IDEAS GROUP': 21, 'AVM GmbH': 22, 'Acronet Co., Ltd.': 23, 'ACCLAIM COMMUNICATIONS': 11404, 'eWings s.r.l.': 26, 'Ubicquia': 15208, 'Avionic Design Development GmbH': 27, 'Zhejiang Moorgen Intelligence Technology Co., Ltd': 5156, 'Pingood Technology Co., Ltd.': 28, 'ZHONGXING TELECOM LTD.': 12399, 'Aventura Technologies, Inc.': 30, 'Siliconware Precision Industries Co., Ltd.': 31, 'FANUC 
# ...

# %%
my_ans = {}

for row in dict_mac:
    my_ans[row] = my_dict[dict_mac[row]]
    
print my_ans
# Out:
# {'681605': 2719, '3831AC': 13384, 'B4B384': 7938, '343DC4': 11679, '000099': 4418, '000098': 11235, '741865': 4060, '000095': 5831, '000094': 3010, '000097': 13757, '000096': 9130, '000091': 14727, '000090': 11961, '000093': 5436, '000092': 11295, '48DD9D': 15623, 'AC932F': 7005, '587FC8': 15493, '881196': 12889, '54D0B4': 1685, '44E137': 5847, '6886E7': 11684, '7C95F3': 4421, '00009E': 8628, '00009D': 8105, 'E4A7A0': 16845, 'F437B7': 4707, '00009A': 10885, '00009C': 2944, '00009B': 5643, '783690': 10568, '1868CB': 12620, '5C6776': 2486, '089734': 7734, '30694B': 10185, 'A0043E': 10260, '001D4E': 12090, '001D4D': 1142, '001D4F': 4707, '001D4A': 3369, '001D4C': 2473, '001D4B': 10765, '001D45': 4421, '001D44': 1483, '001D47': 11441, '001D46': 4421, '001D41': 7903, '001D40': 15675, '001D43': 7338, '001D42': 16773, 'D0737F': 7239, '001D49': 9849, '001D48': 5724, '1CB094': 2957, '8CDF9D': 11403, '500604': 4421, 'E8EB11': 11459, '4048FD': 15733, '68CC9C': 711, '10E7C6': 4738, 'CC2218': 101
# ...

# %%
import json

f1 = open("/home/venky/IdeaProjects/ViterbiHack/mac_index.json",'w')
f2 = open("/home/venky/IdeaProjects/ViterbiHack/company_index.json",'w')

json.dump(my_ans,f1)
json.dump(my_dict,f2)


f1.close()
f1.close()

# %%
f3 = open("/home/venky/IdeaProjects/ViterbiHack/protocols.txt","r")

proc = f3.readlines()

proc_set = set([])
for line in proc:
    print line
    x,y = line.split(" ")
    proc_set.add(y)
    
    
proc_dict = {}
for counter, value in enumerate(proc_set):
    proc_dict[value] = counter
    
f4 = open("/home/venky/Downloads/protocol_index.txt","w")

json.dump(proc_dict,f4)
# Out:
# 130233 TCP
#
# 2784 UDP
#
# 2192 SSDP
#
# 106 ICMP
#
# 1152 NBNS
#
# 1817 TLSv1.2
#
# 117 IGMPv3
#
# 3038    LLMNR
# ValueErrorTraceback (most recent call last)
# <ipython-input-34-caf4739d8193> in <module>()
#       6 for line in proc:
#       7     print line
# ----> 8     x,y = line.split(" ")
#       9     proc_set.add(y)
#      10
#
# ValueError: too many values to unpack

# %%
import pandas as pd
df = pd.read_csv('/home/venky/Downloads/dataset_big.csv', sep=",", header=None, names=["Src Port", "Dest Port", "Protocol", "Packet"])
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2705: DtypeWarning: Columns (0,1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Src Port  Dest Port  Protocol  Packet
# 0  Src Port  Dest Port  Protocol  Packet
# 1      1390         53       udp       1
# 2     33661       1024       udp       1
# 3      1464         53       udp       1
# 4      3593         53       udp       1

# %%
df['Src Port'] = pd.to_numeric(df['Src Port'])
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-11-ce220b6d8f0a> in <module>()
# ----> 1 df['Src Port'] = pd.to_numeric(df['Src Port'])
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/tools/numeric.pyc in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric (pandas/_libs/lib.c:56638)()
#
# ValueError: Unable to parse string "Src Port" at position 0

# %%
import re

non_numeric = re.compile(r'[^\d.]+')
df.loc[df['Src Port'].str.contains(non_numeric)]
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-10-eda9d0a1bc15> in <module>()
#       2
#       3 non_numeric = re.compile(r'[^\d.]+')
# ----> 4 df.loc[df['Src Port'].str.contains(non_numeric)]
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1505             self._has_valid_type(key, axis)
#    1506             return self._get_slice_axis(key, axis=axis)
# -> 1507         elif is_bool_indexer(key):
#    1508             return self._getbool_axis(key, axis=axis)
#    1509         elif is_list_like_indexer(key):
#
# ...

# %%
df.dropna(axis=0, how='all')
# Out:
#         Src Port  Dest Port  Protocol  Packet
# 0       Src Port  Dest Port  Protocol  Packet
# 1           1390         53       udp       1
# 2          33661       1024       udp       1
# 3           1464         53       udp       1
# 4           3593         53       udp       1
# 5          49664         53       udp       1
# 6          32119        111       udp       1
# 7           2142         53       udp       1
# 8              0          0       arp       1
# 9          40726         53       udp       1
# 10         12660         53       udp       1
# 11             0          0       arp       1
# 12             0          0       arp       1
# 13             0          0       arp       1
# 14         48847         53       udp       1
# 15         24266      41049       udp       1
# 16         10393      44307       udp       1
# 17         62539         53       udp       1
# 18         21270        111       udp       1
# ...

# %%
df['Src Port'] = df['Src Port'].replace([df['Src Port'] > 49151], 2)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-13-d59b6be71433> in <module>()
# ----> 1 df['Src Port'] = df['Src Port'].replace([df['Src Port'] > 49151], 2)
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3888                     new_data = self._data.replace(to_replace=to_replace,
#    3889                                                   value=value, inplace=inplace,
# -> 3890                                                   regex=regex)
#    3891             elif to_replace is None:
#    3892                 if not (is_re_compilable(regex) or
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in replace(self, **kwargs)
#    3228
#    3229     def replace(self, **kwargs):
# -> 3230         return self.apply('replace', **kwargs)
#    3231
#    3232     def replace_list(self, src_list, dest_list, inplace=False, regex=False,
#
# ...

# %%
dfs = pd.read_csv('/home/venky/Downloads/dataset_1.csv', sep=",", header=None, names=["Src Port", "Dest Port", "Protocol", "Packet"])

# %%
dfs['Packet'] = pd.to_numeric(dfs['Packet'])
dfs.head()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-33-a5fa6d7c7cdc> in <module>()
# ----> 1 dfs['Packet'] = pd.to_numeric(dfs['Packet'])
#       2 dfs.head()
#
# /home/venky/.local/lib/python2.7/site-packages/pandas/core/tools/numeric.pyc in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric (pandas/_libs/lib.c:56638)()
#
# ValueError: Unable to parse string "Packet" at position 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()
dfs['Packet'].value_counts().plot(ax=ax, kind='bar')

# %%
fp = open("/home/venky/Downloads/dataset_.csv","r")
fp1 = open("/home/venky/Downloads/dataset_1.csv","w")


lines = fp.readlines()
blob = []
for line in lines:
    blob.append(",".join([i.strip() for i in line.split(',')]))

print blob
    
    
for item in blob:
    fp1.write("%s\n" % item)

fp.close()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
dfs = pd.read_csv('/home/venky/Downloads/mergeddata2.csv', sep=",")

# %%
dfs.head()
# Out:
#    Source Port  Destination Port  Protocol  Packet
# 0            1                 1         2       1
# 1            0                 0         2       1
# 2            0                 0         0       1
# 3            1                 1         2       0
# 4            1                 1         2       0

# %%
dfs = dfs.drop('Unnamed: 0', 1)

# %%
dfs.to_csv('filename.csv', header=False,index = False)

# %%
import numpy as np
from numpy import loadtxt
dataset = loadtxt('filename.csv', delimiter=',')

# %%
print dataset
# Out:
# [[  0.00000000e+00   1.00000000e+00   1.00000000e+00   2.00000000e+00
#     1.00000000e+00]
#  [  1.00000000e+00   0.00000000e+00   0.00000000e+00   2.00000000e+00
#     1.00000000e+00]
#  [  2.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     1.00000000e+00]
#  ...,
#  [  1.74857300e+06   1.00000000e+00   0.00000000e+00   1.00000000e+00
#     1.00000000e+00]
#  [  1.74857400e+06   1.00000000e+00   1.00000000e+00   1.00000000e+00
#     1.00000000e+00]
#  [  1.74857500e+06   1.00000000e+00   0.00000000e+00   2.00000000e+00
#     1.00000000e+00]]
